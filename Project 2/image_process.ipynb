# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = r"C:\Users\HP\OneDrive\Pictures\Saved Pictures\WhatsApp Image 2024-12-12 at 20.29.48_b7e216eb.jpg"
img = Image.open(img_path)

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np

# %%
img = np.array(img)
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1600, 1200, 3)

# %%
img
# Out:
# array([[[207, 199, 188],
#         [208, 200, 189],
#         [208, 200, 189],
#         ...,
#         [246, 249, 242],
#         [246, 249, 242],
#         [246, 249, 242]],
#
#        [[207, 199, 188],
#         [208, 200, 189],
#         [208, 200, 189],
#         ...,
#         [246, 249, 242],
#         [246, 249, 242],
#         [246, 249, 242]],
#
#        [[207, 199, 188],
#         [208, 200, 189],
#         [208, 200, 189],
#         ...,
#         [246, 249, 242],
#         [246, 249, 242],
#         [246, 249, 242]],
#
#        ...,
#
#        [[ 43,  48,  52],
#         [ 43,  48,  52],
#         [ 41,  46,  50],
#         ...,
#         [120, 131, 137],
#         [119, 130, 136],
#         [117, 128, 134]],
#
#        [[ 42,  47,  51],
#         [ 41,  46,  50],
#         [ 39,  44,  48],
#         ...,
#         [118, 129, 135],
#         [120, 131, 137],
#         [121, 132, 138]],
#
#        [[ 41,  46,  50],
#         [ 40,  45,  49],
#         [ 37,  42,  46],
#         ...,
#         [117, 128, 134],
#         [121, 132, 138],
#         [124, 135, 141]]], shape=(1600, 1200, 3), dtype=uint8)

# %%
img = Image.open('shaon.jpg')
img_resized = img.resize((400,300))

# %%
img_resized.save('shaon_resized.jpg')

# %%
import matplotlib.image as mpimg

# %%
img_res = mpimg.imread('shaon_resized.jpg')
img_res_plot = plt.imshow(img_res)

# %%
img_res.shape
# Out:
# (300, 400, 3)

# %%
import cv2

# %%
img = np.array(img)
type(img)
# Out:
# numpy.ndarray

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1600, 1200, 3)

# %%
grayscale_image = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1600, 1200)

# %%
plt.imshow(grayscale_image)
plt.axis('off')
plt.show()
