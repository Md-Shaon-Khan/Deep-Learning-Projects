# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

IMAGE_SIZE = 256

# Load model once
model_path = r"F:\Deep Learning Projects\Project 4\models\model_1.keras"
model = tf.keras.models.load_model(model_path)
print("Model loaded successfully.")

# IMPORTANT: Your model output shape = (32, 3)
# So you MUST have exactly 3 classes
class_names = ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']


def predict_image(img_path):
    img = image.load_img(img_path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    predicted_class_name = class_names[predicted_class_index]

    print("Predicted class index:", predicted_class_index)
    print("Predicted class name:", predicted_class_name)

    return predicted_class_name


# Example
img_path = r"F:\Deep Learning Projects\Project 4\PlantVillage\Potato___healthy\00fc2ee5-729f-4757-8aeb-65c3355874f2___RS_HL 1864.JPG"
predict_image("F:/Deep Learning Projects/Project 4/PlantVillage/Potato___Late_blight/00b1f292-23dd-44d4-aad3-c1ffb6a6ad5a___RS_LB 4479.JPG")
# Out:
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Predicted class index: 0
# Predicted class name: Potato___Early_blight
# 'Potato___Early_blight'
